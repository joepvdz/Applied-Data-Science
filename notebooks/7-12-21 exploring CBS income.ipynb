# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, plot_confusion_matrix, recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 

df = pd.read_csv('./mediaan-besteedbaar-inkomen.csv', error_bad_lines=False, sep=',')
#df = df.drop(df.columns[[0,1,5]], axis = 1)
df
# Out:
#                                         zipcode_numbers  Aantal_huishoudens  \
# 0                                                  1011              6100.0
# 1                                                  1012              5700.0
# 2                                                  1013             12300.0
# 3                                                  1014               300.0
# 4                                                  1015              9400.0
# ...                                                 ...                 ...
# 4035                                               9996                 0.0
# 4036                                               9997               300.0
# 4037                                               9998               100.0
# 4038                                               9999                 0.0
# 4039  Bron: CBS. Integrale Inkomens- en Vermogenssta...                 NaN
#
#      Mediaan_besteedbaar_inkomen first_20th_percentile second_20th_percentile  \
# 0                          27500                  30.5                   15.4
# 1                          24900                  34.5                   15.4
# 2                          27200                  31.8                   16.3
# 3                          40700                  18.5                    7.4
# 4                          27500                  30.5                   15.2
# ...                          ...                   ...                    ...
# 4035                           .                     .                      .
# 4036                       35900                  17.0                   25.1
# 4037                           .                     .                      .
# 4038                           .                     .                      .
# 4039                         NaN                   NaN                    NaN
#
#      third_20th_percentile fourth_20th_percentile fifth_20th_percentile
# 0                     12.9                   13.5                  27.6
# 1                     14.9                   13.1                  22.1
# 2                     14.0                   14.8                  23.0
# 3                     13.6                   17.0                  43.5
# 4                     13.3                   13.3                  27.6
# ...                    ...                    ...                   ...
# 4035                     .                      .                     .
# 4036                  19.7                   25.1                  13.1
# 4037                     .                      .                     .
# 4038                     .                      .                     .
# 4039                   NaN                    NaN                   NaN
#
# [4040 rows x 8 columns]

# %%
df = df.dropna()
df
# Out:
#      zipcode_numbers  Aantal_huishoudens Mediaan_besteedbaar_inkomen  \
# 0               1011              6100.0                       27500
# 1               1012              5700.0                       24900
# 2               1013             12300.0                       27200
# 3               1014               300.0                       40700
# 4               1015              9400.0                       27500
# ...              ...                 ...                         ...
# 4034            9995               300.0                       33500
# 4035            9996                 0.0                           .
# 4036            9997               300.0                       35900
# 4037            9998               100.0                           .
# 4038            9999                 0.0                           .
#
#      first_20th_percentile second_20th_percentile third_20th_percentile  \
# 0                     30.5                   15.4                  12.9
# 1                     34.5                   15.4                  14.9
# 2                     31.8                   16.3                  14.0
# 3                     18.5                    7.4                  13.6
# 4                     30.5                   15.2                  13.3
# ...                    ...                    ...                   ...
# 4034                  21.2                   22.9                  26.0
# 4035                     .                      .                     .
# 4036                  17.0                   25.1                  19.7
# 4037                     .                      .                     .
# 4038                     .                      .                     .
#
#      fourth_20th_percentile fifth_20th_percentile
# 0                      13.5                  27.6
# 1                      13.1                  22.1
# 2                      14.8                  23.0
# 3                      17.0                  43.5
# 4                      13.3                  27.6
# ...                     ...                   ...
# 4034                   18.8                  11.1
# 4035                      .                     .
# 4036                   25.1                  13.1
# 4037                      .                     .
# 4038                      .                     .
#
# [4039 rows x 8 columns]

# %%
df.zipcode_numbers.astype(int)
df.dtypes
# Out:
# zipcode_numbers                 object
# Aantal_huishoudens             float64
# Mediaan_besteedbaar_inkomen     object
# first_20th_percentile           object
# second_20th_percentile          object
# third_20th_percentile           object
# fourth_20th_percentile          object
# fifth_20th_percentile           object
# dtype: object

# %%
df.to_csv(r'./Income.csv', index = False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, plot_confusion_matrix, recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 

df = pd.read_csv('./T0_with_questionaires_for_imputation.csv', error_bad_lines=False, sep=',')
#df = df.drop(df.columns[[0,1,5]], axis = 1)
df
# Out:
#       Respondentnummer  who_filled_in  other_location  country_of_birth_child  \
# 0               201102            1.0             2.0                     1.0
# 1               201108            1.0             2.0                     1.0
# 2               201110            1.0             2.0                     1.0
# 3               201113            1.0             2.0                     1.0
# 4               201114            4.0             2.0                     1.0
# ...                ...            ...             ...                     ...
# 1097            311129            1.0             1.0                     1.0
# 1098            311130            1.0             2.0                     1.0
# 1099            311131            1.0             2.0                     1.0
# 1100            311132            1.0             2.0                     1.0
# 1101            311133            1.0             2.0                     1.0
#
# ...

# %%
dft = df['Respondentnummer']
dfr = df['zipcode_numbers']

# %%
column_names = ["Respondentnummer", "zipcode_numbers"]

dfc = pd.DataFrame(columns = column_names)

# %%
dfc['Respondentnummer'] = dft
dfc['zipcode_numbers'] = dfr

# %%
dfc
# Out:
#       Respondentnummer zipcode_numbers
# 0               201102            3191
# 1               201108            3086
# 2               201110            3191
# 3               201113            3192
# 4               201114            3191
# ...                ...             ...
# 1097            311129            9736
# 1098            311130            9736
# 1099            311131            9736
# 1100            311132            9736
# 1101            311133            9736
#
# [1102 rows x 2 columns]

# %%
dfc.to_csv(r'./zipcode_numbers.csv', index = False)
